# %% [markdown]
# ## Importing Needed Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Reading The Data

# %%
data_dir = '../input/digital-currency-time-series/dc.csv'
df = pd.read_csv(data_dir)

# %% [markdown]
# ## Data Exploration and Preprocessing

# %%
df.head()
# Out:
#    Unnamed: 0       open_SAR  open_USD       high_SAR  high_USD  \
# 0  2021-01-30  128437.248512  34246.28  131012.723200  34933.00
# 1  2021-01-29  125144.022272  33368.18  144510.037760  38531.90
# 2  2021-01-28  113870.357376  30362.19  126703.438592  33783.98
# 3  2021-01-27  121753.023104  32464.01  122102.860416  32557.29
# 4  2021-01-26  120966.114176  32254.19  123470.218752  32921.88
#
#          low_SAR   low_USD      close_SAR  close_USD  volume
# 0  123106.880000  32825.00  128333.212416   34218.54   43072
# 1  119695.516160  31915.40  128459.450880   34252.20  231827
# 2  111919.811840  29842.10  125131.570944   33364.86   92621
# 3  109668.146688  29241.72  113885.208960   30366.15   95911
# 4  115652.472448  30837.37  121767.124608   32467.77   84972

# %%
df.tail()
# Out:
#      Unnamed: 0      open_SAR  open_USD      high_SAR  high_USD       low_SAR  \
# 995  2018-05-11  33761.888384   9002.21  33816.606720   9016.80  31282.086400
# 996  2018-05-10  34916.224000   9310.00  35235.458048   9395.12  33641.088000
# 997  2018-05-09  34421.171200   9178.00  35216.256000   9390.00  33622.336000
# 998  2018-05-08  35122.496000   9365.00  35537.665280   9475.70  33980.649216
# 999  2018-05-07  36232.689408   9661.02  36340.138368   9689.67  34432.422400
#
#      low_USD     close_SAR  close_USD  volume
# 995  8341.00  31503.360000    8400.00   48227
# 996  8970.00  33761.850880    9002.20   25055
# 997  8965.00  34916.224000    9310.00   25673
# 998  9060.54  34457.025024    9187.56   25533
# 999  9181.00  35122.496000    9365.00   33787

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   object
#  1   open_SAR    1000 non-null   float64
#  2   open_USD    1000 non-null   float64
#  3   high_SAR    1000 non-null   float64
#  4   high_USD    1000 non-null   float64
#  5   low_SAR     1000 non-null   float64
#  6   low_USD     1000 non-null   float64
#  7   close_SAR   1000 non-null   float64
#  8   close_USD   1000 non-null   float64
#  9   volume      1000 non-null   int64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 78.2+ KB

# %%
df.describe()
# Out:
#             open_SAR      open_USD       high_SAR      high_USD  \
# count    1000.000000   1000.000000    1000.000000   1000.000000
# mean    34825.322255   9285.762120   35789.618165   9542.880270
# std     21728.028028   5793.522832   22785.946842   6075.604427
# min     12045.197184   3211.710000   12288.185600   3276.500000
# 25%     24254.558752   6467.192500   24686.089152   6582.255000
# 50%     30714.632128   8189.695000   31321.953152   8351.630000
# 75%     38317.311744  10216.860000   39077.527200  10419.562500
# max    152217.334784  40586.960000  157329.280000  41950.000000
#
#              low_SAR       low_USD      close_SAR     close_USD         volume
# count    1000.000000   1000.000000    1000.000000   1000.000000    1000.000000
# mean    33796.329057   9011.393200   34917.483572   9310.335850   53100.498000
# std     20565.410145   5483.524463   21928.280072   5846.917681   35329.832031
# min     11837.237504   3156.260000   12045.234688   3211.720000    5743.000000
# 25%     23721.336256   6325.015000   24252.946080   6466.762500   30045.750000
# 50%     30010.869568   8002.045000   30713.263232   8189.330000   43795.500000
# 75%     37158.878816   9907.977500   38329.725568  10220.170000   64909.250000
# max    145215.488000  38720.000000  152201.770624  40582.810000  402201.000000

# %% [markdown]
# ### Resort Data

# %%
df.sort_values(by='Unnamed: 0', ascending=True, inplace=True)

# %% [markdown]
# ### Set Date column as an index

# %%
df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('Unnamed: 0', inplace= True)

# %%
df.head()
# Out:
#                 open_SAR  open_USD      high_SAR  high_USD       low_SAR  \
# Unnamed: 0
# 2018-05-07  36232.689408   9661.02  36340.138368   9689.67  34432.422400
# 2018-05-08  35122.496000   9365.00  35537.665280   9475.70  33980.649216
# 2018-05-09  34421.171200   9178.00  35216.256000   9390.00  33622.336000
# 2018-05-10  34916.224000   9310.00  35235.458048   9395.12  33641.088000
# 2018-05-11  33761.888384   9002.21  33816.606720   9016.80  31282.086400
#
#             low_USD     close_SAR  close_USD  volume
# Unnamed: 0
# 2018-05-07  9181.00  35122.496000    9365.00   33787
# 2018-05-08  9060.54  34457.025024    9187.56   25533
# 2018-05-09  8965.00  34916.224000    9310.00   25673
# 2018-05-10  8970.00  33761.850880    9002.20   25055
# 2018-05-11  8341.00  31503.360000    8400.00   48227

# %%
plt.figure(figsize=(15, 6))
df['open_USD'].plot()
df['close_USD'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['volume'].plot()
plt.ylabel('volume')
plt.xlabel(None)
plt.title("Prices Volume")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['high_USD'].plot()
df['low_USD'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("High & Low Prices")
plt.legend(['High Price', 'Low Price'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Choosing Prediction Column

# %%
n_cols = 1
dataset = df["close_USD"]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1000, 1)

# %% [markdown]
# ### Normalizing Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %% [markdown]
# ### Splitting the Data

# %%
# 75% to Train , 25% to Test
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 750 Test Size : 250

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (750, 1)

# %% [markdown]
# ### Creating training set

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 1

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.16465348],
#        [0.15990542],
#        [0.16318175],
#        [0.15494544],
#        [0.13883138],
#        [0.14059585],
#        [0.14631604],
#        [0.145878  ],
#        [0.14049042],
#        [0.13695827],
#        [0.12923733],
#        [0.13454491],
#        [0.1343758 ],
#        [0.14222919],
#        [0.13832939],
#        [0.12751541],
#        [0.11480077],
#        [0.11675576],
#        [0.11359797],
#        [0.11030559],
#        [0.11044018],
#        [0.10401837],
#        [0.11371277],
#        [0.11142945],
#        [0.11434748],
#        [0.11531079],
#        [0.11849561],
#        [0.1204819 ],
#        [0.11440073],
#        [0.11809342],
#        [0.11899894],
#        [0.11986164],
#        [0.11751651],
#        [0.1145273 ],
#        [0.09508072],
#        [0.09794416],
#        [0.0887927 ],
#        [0.08244501],
#        [0.09162858],
#        [0.08501705],
#        [0.08756127],
#        [0.08664157],
#        [0.09367508],
#        [0.0944444 ],
#        [0.0949876 ],
#        [0.0938458 ],
#        [0.07581475],
#        [0.07862388],
#        [0.07827575],
#        [0.0813538 ],
#        [0.07650459],
#        [0.07818905],
#        [0.07070332],
#        [0.07990669],
#        [0.08504836],
#        [0.08415837],
#        [0.09107495],
#        [0.08836082],
#        [0.09031741],
#        [0.08877129]])]
# y_train: [array([0.09092751])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((690, 60, 1), (690, 1))

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# ### Model Dtructure

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")
# Out:
# 2022-11-13 14:12:54.188078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.196626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.197321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.199194: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-13 14:12:54.199542: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.200234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.200861: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.859567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.860430: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.861135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-13 14:12:54.861716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
# Fitting the LSTM to the Training set
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 2022-11-13 14:12:55.880369: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-11-13 14:12:58.794716: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 22/22 [==============================] - 4s 8ms/step - loss: 0.0031 - mean_absolute_error: 0.0413
# Epoch 2/100
# 22/22 [==============================] - 0s 7ms/step - loss: 4.8903e-04 - mean_absolute_error: 0.0163
# Epoch 3/100
# 22/22 [==============================] - 0s 7ms/step - loss: 3.3978e-04 - mean_absolute_error: 0.0133
# Epoch 4/100
# 22/22 [==============================] - 0s 7ms/step - loss: 3.2798e-04 - mean_absolute_error: 0.0130
# Epoch 5/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.7289e-04 - mean_absolute_error: 0.0116
# Epoch 6/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.5808e-04 - mean_absolute_error: 0.0113
# Epoch 7/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.3492e-04 - mean_absolute_error: 0.0107
# Epoch 8/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.1871e-04 - mean_absolute_error: 0.0104
# Epoch 9/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.1979e-04 - mean_absolute_error: 0.0104
# Epoch 10/100
# 22/22 [==============================] - 0s 7ms/step - loss: 2.0840e-04 - mean_absolute_error: 0.0102
# Epoch 11/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.9107e-04 - mean_absolute_error: 0.0096
# Epoch 12/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.9122e-04 - mean_absolute_error: 0.0097
# Epoch 13/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.8302e-04 - mean_absolute_error: 0.0095
# Epoch 14/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.7647e-04 - mean_absolute_error: 0.0092
# Epoch 15/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.8958e-04 - mean_absolute_error: 0.0097
# Epoch 16/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.9439e-04 - mean_absolute_error: 0.0098
# Epoch 17/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.6415e-04 - mean_absolute_error: 0.0088
# Epoch 18/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.5220e-04 - mean_absolute_error: 0.0086
# Epoch 19/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.6515e-04 - mean_absolute_error: 0.0091
# Epoch 20/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.5411e-04 - mean_absolute_error: 0.0087
# Epoch 21/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.5389e-04 - mean_absolute_error: 0.0090
# Epoch 22/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.4879e-04 - mean_absolute_error: 0.0086
# Epoch 23/100
# 22/22 [==============================] - 0s 13ms/step - loss: 1.3124e-04 - mean_absolute_error: 0.0080
# Epoch 24/100
# 22/22 [==============================] - 0s 8ms/step - loss: 1.5166e-04 - mean_absolute_error: 0.0088
# Epoch 25/100
# 22/22 [==============================] - 0s 10ms/step - loss: 1.4107e-04 - mean_absolute_error: 0.0086
# Epoch 26/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.3119e-04 - mean_absolute_error: 0.0081
# Epoch 27/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.4127e-04 - mean_absolute_error: 0.0086
# Epoch 28/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2049e-04 - mean_absolute_error: 0.0075
# Epoch 29/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.1743e-04 - mean_absolute_error: 0.0073
# Epoch 30/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0898e-04 - mean_absolute_error: 0.0071
# Epoch 31/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.1420e-04 - mean_absolute_error: 0.0074
# Epoch 32/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.1416e-04 - mean_absolute_error: 0.0075
# Epoch 33/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0319e-04 - mean_absolute_error: 0.0070
# Epoch 34/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.2800e-04 - mean_absolute_error: 0.0082
# Epoch 35/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.7411e-05 - mean_absolute_error: 0.0067
# Epoch 36/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.1711e-04 - mean_absolute_error: 0.0079
# Epoch 37/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.6312e-05 - mean_absolute_error: 0.0065
# Epoch 38/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0856e-04 - mean_absolute_error: 0.0072
# Epoch 39/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0010e-04 - mean_absolute_error: 0.0068
# Epoch 40/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3245e-05 - mean_absolute_error: 0.0065
# Epoch 41/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.1312e-04 - mean_absolute_error: 0.0075
# Epoch 42/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.0753e-05 - mean_absolute_error: 0.0065
# Epoch 43/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6963e-05 - mean_absolute_error: 0.0063
# Epoch 44/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5776e-05 - mean_absolute_error: 0.0063
# Epoch 45/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3288e-05 - mean_absolute_error: 0.0068
# Epoch 46/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.0165e-05 - mean_absolute_error: 0.0066
# Epoch 47/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3940e-05 - mean_absolute_error: 0.0066
# Epoch 48/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4522e-05 - mean_absolute_error: 0.0061
# Epoch 49/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5628e-05 - mean_absolute_error: 0.0062
# Epoch 50/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5588e-05 - mean_absolute_error: 0.0065
# Epoch 51/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.1869e-05 - mean_absolute_error: 0.0061
# Epoch 52/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4238e-05 - mean_absolute_error: 0.0063
# Epoch 53/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.4579e-05 - mean_absolute_error: 0.0067
# Epoch 54/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.5887e-05 - mean_absolute_error: 0.0069
# Epoch 55/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.3351e-05 - mean_absolute_error: 0.0060
# Epoch 56/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.9884e-05 - mean_absolute_error: 0.0067
# Epoch 57/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.8736e-05 - mean_absolute_error: 0.0062
# Epoch 58/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.9840e-05 - mean_absolute_error: 0.0058
# Epoch 59/100
# 22/22 [==============================] - 0s 8ms/step - loss: 7.6779e-05 - mean_absolute_error: 0.0058
# Epoch 60/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.0011e-05 - mean_absolute_error: 0.0057
# Epoch 61/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.8525e-05 - mean_absolute_error: 0.0058
# Epoch 62/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.0869e-05 - mean_absolute_error: 0.0066
# Epoch 63/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0619e-04 - mean_absolute_error: 0.0077
# Epoch 64/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5464e-05 - mean_absolute_error: 0.0062
# Epoch 65/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3621e-05 - mean_absolute_error: 0.0067
# Epoch 66/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.3582e-05 - mean_absolute_error: 0.0061
# Epoch 67/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.4303e-05 - mean_absolute_error: 0.0055
# Epoch 68/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.9784e-05 - mean_absolute_error: 0.0059
# Epoch 69/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.7521e-05 - mean_absolute_error: 0.0062
# Epoch 70/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.9482e-05 - mean_absolute_error: 0.0065
# Epoch 71/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.7510e-05 - mean_absolute_error: 0.0056
# Epoch 72/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.4916e-05 - mean_absolute_error: 0.0056
# Epoch 73/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3644e-05 - mean_absolute_error: 0.0068
# Epoch 74/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.1839e-05 - mean_absolute_error: 0.0061
# Epoch 75/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.4825e-05 - mean_absolute_error: 0.0054
# Epoch 76/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.1953e-05 - mean_absolute_error: 0.0065
# Epoch 77/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0291e-04 - mean_absolute_error: 0.0071
# Epoch 78/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0187e-04 - mean_absolute_error: 0.0072
# Epoch 79/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.9316e-05 - mean_absolute_error: 0.0060
# Epoch 80/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.4300e-05 - mean_absolute_error: 0.0054
# Epoch 81/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.2656e-05 - mean_absolute_error: 0.0054
# Epoch 82/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.0780e-05 - mean_absolute_error: 0.0060
# Epoch 83/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.0017e-05 - mean_absolute_error: 0.0061
# Epoch 84/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.9571e-05 - mean_absolute_error: 0.0059
# Epoch 85/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.8762e-05 - mean_absolute_error: 0.0061
# Epoch 86/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.7385e-05 - mean_absolute_error: 0.0058
# Epoch 87/100
# 22/22 [==============================] - 0s 7ms/step - loss: 1.0350e-04 - mean_absolute_error: 0.0074
# Epoch 88/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.1488e-05 - mean_absolute_error: 0.0067
# Epoch 89/100
# 22/22 [==============================] - 0s 10ms/step - loss: 7.6921e-05 - mean_absolute_error: 0.0056
# Epoch 90/100
# 22/22 [==============================] - 0s 9ms/step - loss: 7.1424e-05 - mean_absolute_error: 0.0055
# Epoch 91/100
# 22/22 [==============================] - 0s 9ms/step - loss: 7.1795e-05 - mean_absolute_error: 0.0053
# Epoch 92/100
# 22/22 [==============================] - 0s 8ms/step - loss: 7.5575e-05 - mean_absolute_error: 0.0057
# Epoch 93/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.6650e-05 - mean_absolute_error: 0.0056
# Epoch 94/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6310e-05 - mean_absolute_error: 0.0062
# Epoch 95/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.0236e-05 - mean_absolute_error: 0.0058
# Epoch 96/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.5566e-05 - mean_absolute_error: 0.0057
# Epoch 97/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4034e-05 - mean_absolute_error: 0.0063
# Epoch 98/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3849e-05 - mean_absolute_error: 0.0069
# Epoch 99/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.6766e-05 - mean_absolute_error: 0.0057
# Epoch 100/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.1549e-05 - mean_absolute_error: 0.0062

# %% [markdown]
# ### Model Evaluation

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Predection

# %% [markdown]
# ### Creating testing set

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

x_test = []
y_test = []
n_cols = 1

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((250, 60, 1), (250, 1))

# %%
# Get Prediction
predictions = model.predict(x_test)

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (250, 1)

# %% [markdown]
# ### Root mean square error

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 701.6

# %%
preds_acts = pd.DataFrame(data={'Predictions':predictions.flatten(), 'Actuals':y_test.flatten()})
preds_acts
# Out:
#       Predictions   Actuals
# 0     8667.958984   8841.18
# 1     8656.450195   9204.07
# 2     8961.376953   9575.89
# 3     9345.821289   9427.07
# 4     9282.106445   9697.72
# ..            ...       ...
# 245  29991.105469  32467.77
# 246  30208.470703  30366.15
# 247  27969.140625  33364.86
# 248  31288.488281  34252.20
# 249  32124.873047  34218.54
#
# [250 rows x 2 columns]

# %%
plt.figure(figsize = (16, 6))
plt.plot(preds_acts['Predictions'])
plt.plot(preds_acts['Actuals'])
plt.legend(['Predictions', 'Actuals'])
plt.show()

# %% [markdown]
# ### Visualize Predictions with The Data
# for one feature

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Salaries Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Salary Price', fontsize= 18)
plt.plot(train['close_USD'], linewidth= 3)
plt.plot(test['close_USD'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %% [markdown]
# # Multivariate Predection

# %%
df.head()
# Out:
#                 open_SAR  open_USD      high_SAR  high_USD       low_SAR  \
# Unnamed: 0
# 2018-05-07  36232.689408   9661.02  36340.138368   9689.67  34432.422400
# 2018-05-08  35122.496000   9365.00  35537.665280   9475.70  33980.649216
# 2018-05-09  34421.171200   9178.00  35216.256000   9390.00  33622.336000
# 2018-05-10  34916.224000   9310.00  35235.458048   9395.12  33641.088000
# 2018-05-11  33761.888384   9002.21  33816.606720   9016.80  31282.086400
#
#             low_USD     close_SAR  close_USD  volume
# Unnamed: 0
# 2018-05-07  9181.00  35122.496000    9365.00   33787
# 2018-05-08  9060.54  34457.025024    9187.56   25533
# 2018-05-09  8965.00  34916.224000    9310.00   25673
# 2018-05-10  8970.00  33761.850880    9002.20   25055
# 2018-05-11  8341.00  31503.360000    8400.00   48227

# %% [markdown]
# ### Chose Columns

# %%
n_cols = 4
cols = list(df.loc[:, ['open_USD', 'high_USD', 'low_USD', 'close_USD', 'volume']])
dataset = df[cols]
dataset = pd.DataFrame(dataset)
data = dataset.values

data.shape
# Out:
# (1000, 5)

# %% [markdown]
# ### Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data))

# %%
train_size = int(len(data) * 0.75)
test_size = len(data) - train_size
print("Train Size :",train_size,"Test Size :",test_size)
# Out:
# Train Size : 750 Test Size : 250

# %%
train_data = scaled_data[0:train_size, :]
train_data.shape
# Out:
# (750, 5)

# %%
# Creating a Training set with 60 time-steps
x_train = []
y_train = []
time_steps = 60
n_cols = 5

for i in range(time_steps, len(train_data)):
    x_train.append(train_data[i-time_steps:i, :n_cols])
    y_train.append(train_data[i, :n_cols])
    if i<=time_steps:
        print('X_train: ', x_train)
        print('y_train:' , y_train)
# Out:
# X_train:  [array([[0.17255564, 0.16582854, 0.16940682, 0.16465348, 0.07073637],
#        [0.16463542, 0.16029581, 0.16601966, 0.15990542, 0.04991702],
#        [0.15963211, 0.15807982, 0.16333322, 0.16318175, 0.05027014],
#        [0.16316386, 0.15821221, 0.16347381, 0.15494544, 0.04871134],
#        [0.15492873, 0.1484298 , 0.14578725, 0.13883138, 0.10715889],
#        [0.13897512, 0.1388646 , 0.14050097, 0.14059585, 0.08701552],
#        [0.14083464, 0.14187648, 0.14457816, 0.14631604, 0.05016673],
#        [0.14630002, 0.14489224, 0.14398767, 0.145878  , 0.07982182],
#        [0.14586284, 0.14437509, 0.1474828 , 0.14049042, 0.05645743],
#        [0.14047505, 0.13475636, 0.13853296, 0.13695827, 0.06403453],
#        [0.1369433 , 0.13413578, 0.13560835, 0.12923733, 0.04967992],
#        [0.12915258, 0.12920243, 0.13372159, 0.13454491, 0.04472857],
#        [0.13448204, 0.13224301, 0.13889062, 0.1343758 , 0.02888074],
#        [0.13436111, 0.13788512, 0.14080746, 0.14222919, 0.03585247],
#        [0.14221336, 0.13753113, 0.14477499, 0.13832939, 0.03978479],
#        [0.13846543, 0.13248555, 0.13437422, 0.12751541, 0.0453188 ],
#        [0.12750176, 0.12296275, 0.12003068, 0.11480077, 0.09374764],
#        [0.11478826, 0.11517525, 0.11558767, 0.11675576, 0.08097201],
#        [0.11684952, 0.11307614, 0.11674503, 0.11359797, 0.05295895],
#        [0.11358533, 0.11231205, 0.11651587, 0.11030559, 0.03460896],
#        [0.11029465, 0.1066234 , 0.11457878, 0.11044018, 0.03269703],
#        [0.11042816, 0.10758013, 0.10971175, 0.10401837, 0.05416967],
#        [0.10400706, 0.11024345, 0.10900681, 0.11371277, 0.08491189],
#        [0.11387937, 0.11099332, 0.11540519, 0.11142945, 0.06633237],
#        [0.11158079, 0.11435479, 0.11728941, 0.11434748, 0.06314162],
#        [0.11433502, 0.11201598, 0.11807757, 0.11531079, 0.0567929 ],
#        [0.11529823, 0.11431161, 0.12036811, 0.11849561, 0.05291103],
#        [0.11839653, 0.11662223, 0.12495143, 0.1204819 , 0.05489106],
#        [0.12046876, 0.11594554, 0.12063523, 0.11440073, 0.06687972],
#        [0.11438826, 0.11385031, 0.11814674, 0.11809342, 0.06552775],
#        [0.11812443, 0.11435479, 0.12121307, 0.11899894, 0.0541949 ],
#        [0.11898462, 0.11606139, 0.1255138 , 0.11986164, 0.048729  ],
#        [0.11984856, 0.11447115, 0.12301125, 0.11751651, 0.04452678],
#        [0.1175037 , 0.11396641, 0.12073365, 0.1145273 , 0.03429367],
#        [0.11451482, 0.10899531, 0.09747428, 0.09508072, 0.1175383 ],
#        [0.09507067, 0.09426351, 0.09711408, 0.09794416, 0.07266596],
#        [0.09793353, 0.09344926, 0.09219334, 0.0887927 , 0.07813942],
#        [0.08878309, 0.08665107, 0.08329889, 0.08244501, 0.10200828],
#        [0.0824361 , 0.0890403 , 0.0872726 , 0.09162858, 0.09770266],
#        [0.09169062, 0.08766106, 0.0901494 , 0.08501705, 0.06122969],
#        [0.08477   , 0.0849031 , 0.08898389, 0.08756127, 0.04170429],
#        [0.08751219, 0.08565374, 0.0918278 , 0.08664157, 0.03557502],
#        [0.0864837 , 0.09096358, 0.09064682, 0.09367508, 0.06577746],
#        [0.0936363 , 0.09218819, 0.09832318, 0.0944444 , 0.04683472],
#        [0.09440178, 0.09155442, 0.09547787, 0.0949876 , 0.05200046],
#        [0.09502278, 0.09097961, 0.09887346, 0.0938458 , 0.04965217],
#        [0.09380486, 0.08940153, 0.07768249, 0.07581475, 0.11707167],
#        [0.0758312 , 0.07714585, 0.08020023, 0.07862388, 0.05266384],
#        [0.07861539, 0.07714068, 0.07293215, 0.07827575, 0.10518643],
#        [0.07829352, 0.07947302, 0.08170429, 0.0813538 , 0.08429897],
#        [0.08134501, 0.0774701 , 0.08094593, 0.07650459, 0.03438952],
#        [0.07636551, 0.07534694, 0.07914634, 0.07818905, 0.03400612],
#        [0.07820737, 0.07489651, 0.07509728, 0.07070332, 0.06265985],
#        [0.07061625, 0.07818015, 0.07377571, 0.07990669, 0.07104914],
#        [0.07989806, 0.08410126, 0.08519267, 0.08504836, 0.08115866],
#        [0.08506619, 0.08182761, 0.08701953, 0.08415837, 0.05503483],
#        [0.08425656, 0.08813529, 0.08759934, 0.09107495, 0.07689844],
#        [0.09106508, 0.08798919, 0.09298094, 0.08836082, 0.08302014],
#        [0.08827499, 0.09071897, 0.09236514, 0.09031741, 0.04496819],
#        [0.09026883, 0.08883344, 0.09270875, 0.08877129, 0.07397505]])]
# y_train: [array([0.08876168, 0.08719252, 0.09191216, 0.09092751, 0.05966332])]

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input to (n_samples, time_steps, n_feature)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_cols))

# %%
x_train.shape , y_train.shape
# Out:
# ((690, 60, 5), (690, 5))

# %%
model2 = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], n_cols)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(n_cols)
])

model2.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 60, 50)            11200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 85
# =================================================================
# Total params: 43,333
# Trainable params: 43,333
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the LSTM to the Training set
history2 = model2.fit(x_train, y_train, epochs= 100, batch_size= 32)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 2s 7ms/step - loss: 0.0029 - mean_absolute_error: 0.0362
# Epoch 2/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0221
# Epoch 3/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0194
# Epoch 4/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0187
# Epoch 5/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0179
# Epoch 6/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0180
# Epoch 7/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0174
# Epoch 8/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0170
# Epoch 9/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0173
# Epoch 10/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0165
# Epoch 11/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0170
# Epoch 12/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0162
# Epoch 13/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0159
# Epoch 14/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0157
# Epoch 15/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.9881e-04 - mean_absolute_error: 0.0154
# Epoch 16/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.9078e-04 - mean_absolute_error: 0.0159
# Epoch 17/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0158
# Epoch 18/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.9740e-04 - mean_absolute_error: 0.0156
# Epoch 19/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.9131e-04 - mean_absolute_error: 0.0154
# Epoch 20/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0166
# Epoch 21/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.9387e-04 - mean_absolute_error: 0.0157
# Epoch 22/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.7033e-04 - mean_absolute_error: 0.0149
# Epoch 23/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.4702e-04 - mean_absolute_error: 0.0148
# Epoch 24/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.7915e-04 - mean_absolute_error: 0.0152
# Epoch 25/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.5013e-04 - mean_absolute_error: 0.0146
# Epoch 26/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.6781e-04 - mean_absolute_error: 0.0149
# Epoch 27/100
# 22/22 [==============================] - 0s 11ms/step - loss: 9.3365e-04 - mean_absolute_error: 0.0141
# Epoch 28/100
# 22/22 [==============================] - 0s 9ms/step - loss: 9.4411e-04 - mean_absolute_error: 0.0143
# Epoch 29/100
# 22/22 [==============================] - 0s 9ms/step - loss: 9.5801e-04 - mean_absolute_error: 0.0141
# Epoch 30/100
# 22/22 [==============================] - 0s 8ms/step - loss: 9.5483e-04 - mean_absolute_error: 0.0146
# Epoch 31/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.4062e-04 - mean_absolute_error: 0.0145
# Epoch 32/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.4167e-04 - mean_absolute_error: 0.0144
# Epoch 33/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.1597e-04 - mean_absolute_error: 0.0139
# Epoch 34/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.5595e-04 - mean_absolute_error: 0.0144
# Epoch 35/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.4018e-04 - mean_absolute_error: 0.0144
# Epoch 36/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.3134e-04 - mean_absolute_error: 0.0143
# Epoch 37/100
# 22/22 [==============================] - 0s 7ms/step - loss: 9.0835e-04 - mean_absolute_error: 0.0136
# Epoch 38/100
# 22/22 [==============================] - 0s 8ms/step - loss: 9.0087e-04 - mean_absolute_error: 0.0135
# Epoch 39/100
# 22/22 [==============================] - 0s 10ms/step - loss: 9.2896e-04 - mean_absolute_error: 0.0136
# Epoch 40/100
# 22/22 [==============================] - 0s 10ms/step - loss: 9.0128e-04 - mean_absolute_error: 0.0137
# Epoch 41/100
# 22/22 [==============================] - 0s 10ms/step - loss: 9.3200e-04 - mean_absolute_error: 0.0139
# Epoch 42/100
# 22/22 [==============================] - 0s 10ms/step - loss: 9.0299e-04 - mean_absolute_error: 0.0137
# Epoch 43/100
# 22/22 [==============================] - 0s 10ms/step - loss: 9.5776e-04 - mean_absolute_error: 0.0147
# Epoch 44/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.9634e-04 - mean_absolute_error: 0.0138
# Epoch 45/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.8755e-04 - mean_absolute_error: 0.0136
# Epoch 46/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.7465e-04 - mean_absolute_error: 0.0133
# Epoch 47/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6798e-04 - mean_absolute_error: 0.0128
# Epoch 48/100
# 22/22 [==============================] - 0s 9ms/step - loss: 8.6014e-04 - mean_absolute_error: 0.0130
# Epoch 49/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.9510e-04 - mean_absolute_error: 0.0134
# Epoch 50/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6062e-04 - mean_absolute_error: 0.0128
# Epoch 51/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6296e-04 - mean_absolute_error: 0.0129
# Epoch 52/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5779e-04 - mean_absolute_error: 0.0125
# Epoch 53/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5745e-04 - mean_absolute_error: 0.0130
# Epoch 54/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5697e-04 - mean_absolute_error: 0.0125
# Epoch 55/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.5547e-04 - mean_absolute_error: 0.0125
# Epoch 56/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4846e-04 - mean_absolute_error: 0.0128
# Epoch 57/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4385e-04 - mean_absolute_error: 0.0123
# Epoch 58/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4835e-04 - mean_absolute_error: 0.0128
# Epoch 59/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4397e-04 - mean_absolute_error: 0.0123
# Epoch 60/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6147e-04 - mean_absolute_error: 0.0132
# Epoch 61/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.6538e-04 - mean_absolute_error: 0.0128
# Epoch 62/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.2001e-04 - mean_absolute_error: 0.0123
# Epoch 63/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.4116e-04 - mean_absolute_error: 0.0128
# Epoch 64/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.2004e-04 - mean_absolute_error: 0.0132
# Epoch 65/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.2620e-04 - mean_absolute_error: 0.0123
# Epoch 66/100
# 22/22 [==============================] - 0s 7ms/step - loss: 8.1199e-04 - mean_absolute_error: 0.0121
# Epoch 67/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.7825e-04 - mean_absolute_error: 0.0117
# Epoch 68/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.7232e-04 - mean_absolute_error: 0.0117
# Epoch 69/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.6382e-04 - mean_absolute_error: 0.0118
# Epoch 70/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.6893e-04 - mean_absolute_error: 0.0120
# Epoch 71/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.5425e-04 - mean_absolute_error: 0.0123
# Epoch 72/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.5970e-04 - mean_absolute_error: 0.0123
# Epoch 73/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.7581e-04 - mean_absolute_error: 0.0135
# Epoch 74/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.2889e-04 - mean_absolute_error: 0.0117
# Epoch 75/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.1567e-04 - mean_absolute_error: 0.0115
# Epoch 76/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.1134e-04 - mean_absolute_error: 0.0114
# Epoch 77/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.0825e-04 - mean_absolute_error: 0.0117
# Epoch 78/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.8592e-04 - mean_absolute_error: 0.0114
# Epoch 79/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.9465e-04 - mean_absolute_error: 0.0115
# Epoch 80/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.0383e-04 - mean_absolute_error: 0.0116
# Epoch 81/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.4295e-04 - mean_absolute_error: 0.0121
# Epoch 82/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.9852e-04 - mean_absolute_error: 0.0115
# Epoch 83/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.8070e-04 - mean_absolute_error: 0.0111
# Epoch 84/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.8735e-04 - mean_absolute_error: 0.0116
# Epoch 85/100
# 22/22 [==============================] - 0s 8ms/step - loss: 6.7286e-04 - mean_absolute_error: 0.0112
# Epoch 86/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.9823e-04 - mean_absolute_error: 0.0112
# Epoch 87/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.3068e-04 - mean_absolute_error: 0.0120
# Epoch 88/100
# 22/22 [==============================] - 0s 7ms/step - loss: 7.1005e-04 - mean_absolute_error: 0.0121
# Epoch 89/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.9575e-04 - mean_absolute_error: 0.0119
# Epoch 90/100
# 22/22 [==============================] - 0s 8ms/step - loss: 6.7404e-04 - mean_absolute_error: 0.0114
# Epoch 91/100
# 22/22 [==============================] - 0s 12ms/step - loss: 6.8056e-04 - mean_absolute_error: 0.0114
# Epoch 92/100
# 22/22 [==============================] - 0s 9ms/step - loss: 6.6120e-04 - mean_absolute_error: 0.0108
# Epoch 93/100
# 22/22 [==============================] - 0s 8ms/step - loss: 6.7818e-04 - mean_absolute_error: 0.0112
# Epoch 94/100
# 22/22 [==============================] - 0s 8ms/step - loss: 6.8290e-04 - mean_absolute_error: 0.0116
# Epoch 95/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.8042e-04 - mean_absolute_error: 0.0113
# Epoch 96/100
# 22/22 [==============================] - 0s 8ms/step - loss: 6.6079e-04 - mean_absolute_error: 0.0109
# Epoch 97/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.5938e-04 - mean_absolute_error: 0.0109
# Epoch 98/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.5730e-04 - mean_absolute_error: 0.0111
# Epoch 99/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.7712e-04 - mean_absolute_error: 0.0111
# Epoch 100/100
# 22/22 [==============================] - 0s 7ms/step - loss: 6.5887e-04 - mean_absolute_error: 0.0106

# %%
plt.figure(figsize=(12, 8))
plt.plot(history2.history["loss"])
plt.plot(history2.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Creating testing set

# %%
# Creating a testing set with 60 time-steps and 1 output
time_steps = 60
test_data = scaled_data[train_size - time_steps:, :]

# %%
x_test = []
y_test = []
n_cols = 5

for i in range(time_steps, len(test_data)):
    x_test.append(test_data[i-time_steps:i, 0:n_cols])
    y_test.append(test_data[i, 0:n_cols])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_cols))

# %%
x_test.shape , y_test.shape
# Out:
# ((250, 60, 5), (250, 5))

# %%
# Get Prediction
predictions = model2.predict(x_test)

# %%
#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# (250, 5)

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform(y_test)

# %%
RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 825.94
